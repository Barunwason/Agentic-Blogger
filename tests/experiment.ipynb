# %%
import sys
import os

# Add the 'src' folder to sys.path
src_path = "/Users/barunwason/Agentic_Ai/blog_ai/src"
if src_path not in sys.path:
    sys.path.append(src_path)

print("Updated sys.path:", sys.path)  # Debugging: Confirm the correct path is added
# Out:
# Updated sys.path: ['/opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/barunwason/Library/Python/3.11/lib/python/site-packages', '/opt/homebrew/lib/python3.11/site-packages', '/Users/barunwason/Agentic_Ai/blog_ai/src']

# %%
from blog_ai.main import run
run()
# Out:
# # Agent: Depression Content Planner
# ## Task: 1. Prioritize the latest trends, key players,  and noteworthy news on Depression.\n 2. Identify the target audience, considering  their interests and pain points.\n 3. Develop a detailed content outline including  an introduction, key points, and a call to action.\n 4. Include SEO keywords and relevant data or sources.
#
#
#
# # Agent: Depression Content Planner
# ## Final Answer:
# **Content Plan: Understanding and Managing Depression**
#
# **1. Latest Trends, Key Players, and Noteworthy News:**
#
# * **Trend:** Increased focus on integrating technology into mental health care (e.g., telehealth, AI-powered mental health apps).  Key players include companies like Talkspace, BetterHelp, and Woebot.  Noteworthy news includes the FDA's approval of new digital therapeutics for depression.
# ...
